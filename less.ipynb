# %% [markdown]
# pip install pandas
# pip install numpy
# pip instal matplotlib
# pip install seaborn
#
# .ipynb
#
# # Заголовок
# ## Заголовок 2

# %%
import numpy as np

# %%
data = [1, 2, 3, 4, 5]
mean = np.mean(data)
print("Среднее арифметическое: ", mean)
# Out:
# Среднее арифметическое:  3.0

# %%
median = np.median(data)
print("Медиана: ", median)
# Out:
# Медиана:  3.0

# %%
data = [1, 2, 3, 3, 4, 4, 4, 5]

values, counts = np.unique(data, return_counts=True)
mode = values[np.argmax(counts)]
print("Мода: ", mode)
# Out:
# Мода:  4

# %%
from scipy import stats

data = [1, 2, 3, 3, 4, 4, 4, 5]
mode1 = stats.mode(data)
print("Мода: ", mode1[0])
# Out:
# Мода:  4

# %%
import pandas as pd

# %%
df = pd.read_csv('./Churn_Modelling.csv', sep=',', encoding='utf-8')

# %%
df.head(10)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
# 8          9    15792365        He          501    France    Male   44
# 9         10    15592389        H?          684    France    Male   27
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
# 5       8  113755.78              2          1               0
# 6       7       0.00              2          1               1
# 7       4  115046.74              4          1               0
# 8       4  142051.07              2          0               1
# 9       2  134603.88              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0
# 5        149756.71       1
# 6         10062.80       0
# 7        119346.88       1
# 8         74940.50       0
# 9         71725.73       0

# %%
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0

# %%
df.sample(10)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 5615       5616    15775339       Lori          520    France  Female   29
# 2166       2167    15780650   Biryukov          667    France    Male   40
# 4132       4133    15737571   Matveyev          540     Spain  Female   28
# 1737       1738    15683677  Schiavone          769     Spain    Male   39
# 981         982    15566156   Franklin          749   Germany  Female   44
# 3598       3599    15632079      Hardy          720   Germany  Female   37
# 1805       1806    15607381       King          769   Germany  Female   31
# 4119       4120    15588197   Endrizzi          670    France    Male   36
# 5509       5510    15746805    Thomson          597    France    Male   33
# 8489       8490    15686538      Nixon          522    France  Female   41
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 5615       8   95947.76              1          1               0
# 2166       9       0.00              1          1               1
# 4132       6   84121.04              1          0               1
# 1737       9       0.00              1          1               1
# 981        0   71497.79              2          0               0
# 3598       8  156282.79              1          1               0
# 1805       7  148913.72              2          1               0
# 4119       7       0.00              2          0               0
# 5509       9       0.00              2          1               0
# 8489       7       0.00              2          0               1
#
#       EstimatedSalary  Exited
# 5615          4696.44       0
# 2166         96670.20       0
# 4132         80698.54       0
# 1737         47722.79       0
# 981         151083.80       0
# 3598         45985.52       0
# 1805         53817.23       0
# 4119         59571.50       0
# 5509         49374.82       0
# 8489        176780.39       0

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
df['Age'].min()
# Out:
# 18

# %%
df['Age'].max()
# Out:
# 92

# %%
df[['Age', 'Balance']].mean()
# Out:
# Age           38.921800
# Balance    76485.889288
# dtype: float64

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
df['Gender'] == 'Male'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995     True
# 9996     True
# 9997    False
# 9998     True
# 9999    False
# Name: Gender, Length: 10000, dtype: bool

# %%
df[(df['Gender'] == 'Male') & (df['Geography'] == 'France')]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography Gender  Age  \
# 6             7    15592531   Bartlett          822    France   Male   50
# 8             9    15792365         He          501    France   Male   44
# 9            10    15592389         H?          684    France   Male   27
# 10           11    15767821     Bearce          528    France   Male   31
# 20           21    15577657   McDonald          732    France   Male   41
# ...         ...         ...        ...          ...       ...    ...  ...
# 9985       9986    15586914     Nepean          659    France   Male   36
# 9988       9989    15589329    Pirozzi          775    France   Male   30
# 9993       9994    15569266     Rahman          644    France   Male   28
# 9995       9996    15606229   Obijiaku          771    France   Male   39
# 9996       9997    15569892  Johnstone          516    France   Male   35
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 6          7       0.00              2          1               1
# 8          4  142051.07              2          0               1
# 9          2  134603.88              1          1               1
# 10         6  102016.72              2          0               0
# 20         8       0.00              2          1               1
# ...      ...        ...            ...        ...             ...
# 9985       6  123841.49              2          1               0
# 9988       4       0.00              2          1               0
# 9993       7  155060.41              1          1               0
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
#
#       EstimatedSalary  Exited
# 6            10062.80       0
# 8            74940.50       0
# 9            71725.73       0
# 10           80181.12       0
# 20          170886.17       0
# ...               ...     ...
# 9985         96833.00       0
# 9988         49337.84       0
# 9993         29179.52       0
# 9995         96270.64       0
# 9996        101699.77       0
#
# [2753 rows x 14 columns]

# %%
df['123'] = 1

# %%
def age_set(x):
    if x <= 18:
        res = "Дети"
    elif x <= 50:
        res = "Взрослые"
    else:
        res = "Пенсионеры"
    return res

# %%
df['Возрастная группа'] = df['Age'].apply(age_set)

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited  123 Возрастная группа
# 0           101348.88       1    1          Взрослые
# 1           112542.58       0    1          Взрослые
# 2           113931.57       1    1          Взрослые
# 3            93826.63       0    1          Взрослые
# 4            79084.10       0    1          Взрослые
# ...               ...     ...  ...               ...
# 9995         96270.64       0    1          Взрослые
# 9996        101699.77       0    1          Взрослые
# 9997         42085.58       1    1          Взрослые
# 9998         92888.52       1    1          Взрослые
# 9999         38190.78       0    1          Взрослые
#
# [10000 rows x 16 columns]

# %%
df.sample(20)
# Out:
#       RowNumber  CustomerId         Surname  CreditScore Geography  Gender  \
# 3884       3885    15735788      Chiagoziem          709    France    Male
# 6575       6576    15651883        Genovesi          794   Germany  Female
# 5261       5262    15814022       Lassetter          714    France  Female
# 325         326    15736601             Tai          716    France    Male
# 4970       4971    15614893            Meng          689     Spain    Male
# 3963       3964    15629603          Chuang          607    France    Male
# 2808       2809    15615991       Udegbulam          654    France    Male
# 4365       4366    15716328          Miller          501    France  Female
# 3836       3837    15602797  Okwudilichukwu          645     Spain  Female
# 7542       7543    15768777            Wang          507     Spain  Female
# 806         807    15613319            Rice          793    France  Female
# 4769       4770    15770345        Kovaleva          559     Spain  Female
# 3554       3555    15662865          Storey          658     Spain    Male
# 7640       7641    15572361           Chill          790   Germany  Female
# 2374       2375    15726186        Genovese          639     Spain    Male
# 4163       4164    15636396         Jackson          627    France  Female
# 814         815    15641655           Black          700    France  Female
# 8967       8968    15579131           Ricci          835    France    Male
# 6761       6762    15746183             Pye          573    France  Female
# 5099       5100    15731555       Ross-Watt          595   Germany  Female
#
#       Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 3884   31       6       0.00              2          1               1
# 6575   55       6  115796.70              1          1               0
# 5261   26       9   89928.99              1          1               0
# 325    35       4  144428.87              1          1               0
# 4970   38       2       0.00              1          1               1
# 3963   31       8       0.00              2          1               1
# 2808   42       7   99263.09              1          1               1
# 4365   40       2       0.00              2          0               0
# 3836   49       5  110132.55              3          0               1
# 7542   34       4       0.00              2          1               1
# 806    33       0       0.00              1          0               0
# 4769   31       1  139183.06              1          0               1
# 3554   36       1       0.00              2          0               1
# 7640   34       2  164011.48              1          1               0
# 2374   29       4  133434.57              2          1               0
# 4163   35       7       0.00              2          0               1
# 814    26       2       0.00              2          0               0
# 8967   25       7       0.00              2          1               1
# 6761   27       4       0.00              2          1               1
# 5099   45       9  106000.12              1          0               0
#
#       EstimatedSalary  Exited  123 Возрастная группа
# 3884         71009.84       0    1          Взрослые
# 6575        160526.36       1    1        Пенсионеры
# 5261         46203.31       0    1          Взрослые
# 325         134132.65       0    1          Взрослые
# 4970         82709.80       0    1          Взрослые
# 3963         43196.50       0    1          Взрослые
# 2808         67607.90       0    1          Взрослые
# 4365        141946.92       0    1          Взрослые
# 3836        187689.91       1    1          Взрослые
# 7542         60688.38       0    1          Взрослые
# 806         175544.02       0    1          Взрослые
# 4769        143360.56       0    1          Взрослые
# 3554         84927.42       0    1          Взрослые
# 7640        199420.41       0    1          Взрослые
# 2374         97983.44       0    1          Взрослые
# 4163        193022.44       0    1          Взрослые
# 814          50051.42       0    1          Взрослые
# 8967         83449.65       0    1          Взрослые
# 6761        157549.60       0    1          Взрослые
# 5099        191448.96       1    1          Взрослые
